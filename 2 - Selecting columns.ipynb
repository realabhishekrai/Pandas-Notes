# %%
import pandas as pd

# %%
movies_data = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_data[['original_title']] #this is dataFrame type
#type(movies_data[['original_title']])
# Out:
#                                 original_title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
# [4803 rows x 1 columns]

# %%
movies_data['original_title'] #this is series type
#type(movies_data['original_title'])
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: original_title, Length: 4803, dtype: object

# %%
#For getting more than two coulmms, pass list to pandas
movies_data[['original_title','vote_average']]
# Out:
#                                 original_title  vote_average
# 0                                       Avatar           7.2
# 1     Pirates of the Caribbean: At World's End           6.9
# 2                                      Spectre           6.3
# 3                        The Dark Knight Rises           7.6
# 4                                  John Carter           6.1
# ...                                        ...           ...
# 4798                               El Mariachi           6.6
# 4799                                 Newlyweds           5.9
# 4800                 Signed, Sealed, Delivered           7.0
# 4801                          Shanghai Calling           5.7
# 4802                         My Date with Drew           6.3
#
# [4803 rows x 2 columns]

# %%
movies_data[['original_title','original_language','vote_average','vote_count','runtime']].head()
# Out:
#                              original_title original_language  vote_average  \
# 0                                    Avatar                en           7.2
# 1  Pirates of the Caribbean: At World's End                en           6.9
# 2                                   Spectre                en           6.3
# 3                     The Dark Knight Rises                en           7.6
# 4                               John Carter                en           6.1
#
#    vote_count  runtime
# 0       11800    162.0
# 1        4500    169.0
# 2        4466    148.0
# 3        9106    165.0
# 4        2124    132.0
