# %%
import pandas as pd

# %%
movies_data = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies_data.iloc[0] #use to access row
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                        150.438
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
type(movies_data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
movies_data.iloc[0:2]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
type(movies_data.iloc[0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
#You can pass the rows numbers to access all of them
movies_data.iloc[[0,5,14,18]]
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 14  225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 18  225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
#
#                                            homepage     id  \
# 0                       http://www.avatarmovie.com/  19995
# 5   http://www.sonypictures.com/movies/spider-man3/    559
# 14                       http://www.manofsteel.com/  49521
# 18  http://www.sonypictures.com/movies/meninblack3/  41154
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 5   [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 14  [{"id": 83, "name": "saving the world"}, {"id"...                en
# ...

# %%
# iloc for rows and columns togehter comman seprated lef side -- rows right side -- columns
movies_data.iloc[0,6]
# Out:
# 'Avatar'

# %%
movies_data.iloc[[0,5,14,18],[6,16]]
# Out:
#     original_title                               tagline
# 0           Avatar           Enter the World of Pandora.
# 5     Spider-Man 3                    The battle within.
# 14    Man of Steel  You will believe that a man can fly.
# 18  Men in Black 3             They are back... in time.

# %%
# you can also perform slicing with rows and columns
movies_data.iloc[[0,15,14,18], 0:2]
# Out:
#        budget                                             genres
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 14  225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 18  225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...

# %%
movies_data.iloc[[0,15,14,18], 5:14]
# Out:
#    original_language                            original_title  \
# 0                 en                                    Avatar
# 15                en  The Chronicles of Narnia: Prince Caspian
# 14                en                              Man of Steel
# 18                en                            Men in Black 3
#
#                                              overview  popularity  \
# 0   In the 22nd century, a paraplegic Marine is di...  150.437577
# 15  One year after their incredible adventures in ...   53.978602
# 14  A young boy learns that he has extraordinary p...   99.398009
# 18  Agents J (Will Smith) and K (Tommy Lee Jones) ...   52.035179
#
#                                  production_companies  \
# 0   [{"name": "Ingenious Film Partners", "id": 289...
# 15  [{"name": "Walt Disney", "id": 5888}, {"name":...
# 14  [{"name": "Legendary Pictures", "id": 923}, {"...
# 18  [{"name": "Amblin Entertainment", "id": 56}, {...
#
# ...
